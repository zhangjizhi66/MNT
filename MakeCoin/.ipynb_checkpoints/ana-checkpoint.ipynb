// %%
int runid = 100;

// %% [markdown]
// #### MakeCoin 生成的ROOT文件：coin0089.root

// %%
TFile *f1 = new TFile(Form("../COIN_ROOT/coin%04d.root",runid));
TTree *treeMe = (TTree*)f1->Get("tree");
TCanvas *c1 = new TCanvas;

// %% [markdown]
// #### ana 生成的ROOT文件：g0089.root

// %%
TFile *f2 = new TFile(Form("/data/d3/DataZhu/ANA_ROOT/g%04d.root",runid));
TTree *treeLi = (TTree*)f2->Get("tree");

// %% [markdown]
// #### 验证与Chico事件符合的Gamma事件数

// %%
cout<<"coin0089.root"<<endl;
treeMe->Scan("ts:ng:ntk","","colsize=15",10,0);
cout<<endl<<"g0089.root"<<endl;
treeLi->Scan("ts:ngam:nGam","","colsize=15",10,0);
// Out:
// coin0089.root
// ******************************************************************
// *    Row   *              ts *              ng *             ntk *
// ******************************************************************
// *        0 *   4871674455920 *               6 *               4 *
// *        1 *   4871674698480 *               2 *               1 *
// *        2 *   4871675220490 *               2 *               2 *
// *        3 *   4871675461980 *               2 *               2 *
// *        4 *   4871676099280 *              10 *               8 *
// *        5 *   4871676380940 *               3 *               2 *
// *        6 *   4871676532370 *               7 *               6 *
// *        7 *   4871676725860 *               5 *               5 *
// *        8 *   4871677222380 *               2 *               2 *
// *        9 *   4871677513200 *              11 *               6 *
// ******************************************************************
//
// g0089.root
// ******************************************************************
// *    Row   *              ts *            ngam *            nGam *
// ******************************************************************
// *        0 *   4871674455920 *               6 *               4 *
// *        1 *   4871674698480 *               2 *               1 *
// *        2 *   4871675220490 *               2 *               2 *
// *        3 *   4871675461980 *               2 *               2 *
// *        4 *   4871676099280 *              10 *               8 *
// *        5 *   4871676380940 *               3 *               2 *
// *        6 *   4871676532370 *               7 *               6 *
// *        7 *   4871676725860 *               5 *               5 *
// *        8 *   4871677222380 *               2 *               2 *
// *        9 *   4871677513200 *              11 *               6 *
// ******************************************************************

// %% [markdown]
// #### 验证Gamma信息

// %%
cout<<"coin0089.root"<<endl;
treeMe->Scan("ts:ge:gdt:tke","","colsize=15",4,0);
cout<<endl<<"g0089.root"<<endl;
treeLi->Scan("ts:ge:gdt:Ge","","colsize=15",4,0);
// Out:
// coin0089.root
// ***********************************************************************************************
// *    Row   * Instance *              ts *              ge *             gdt *             tke *
// ***********************************************************************************************
// *        0 *        0 *   4871674455920 * 3009.6225585937 *             -12 * 3009.6228027343 *
// *        0 *        1 *   4871674455920 * 530.79089355468 *             -14 * 530.79089355468 *
// *        0 *        2 *   4871674455920 * 95.217460632324 *              -7 * 283.14837646484 *
// *        0 *        3 *   4871674455920 * 788.62329101562 *             -22 * 347.41146850585 *
// *        0 *        4 *   4871674455920 * 347.41143798828 *              -5 *                 *
// *        0 *        5 *   4871674455920 * 187.93092346191 *              -4 *                 *
// *        1 *        0 *   4871674698480 * 326.07614135742 *               9 * 631.66729736328 *
// *        1 *        1 *   4871674698480 * 305.59121704101 *               3 *                 *
// *        2 *        0 *   4871675220490 * 372.71896362304 *             -17 * 372.71896362304 *
// *        2 *        1 *   4871675220490 * 55.163105010986 *             -36 * 55.163108825683 *
// *        3 *        0 *   4871675461980 * 1263.1059570312 *              -6 * 1263.1058349609 *
// *        3 *        1 *   4871675461980 * 421.09942626953 *              -3 * 421.09939575195 *
// ***********************************************************************************************
//
// g0089.root
// ***********************************************************************************************
// *    Row   * Instance *              ts *              ge *             gdt *              Ge *
// ***********************************************************************************************
// *        0 *        0 *   4871674455920 * 3009.6225585937 *             -12 * 3009.6228027343 *
// *        0 *        1 *   4871674455920 * 530.79089355468 *             -14 * 530.79089355468 *
// *        0 *        2 *   4871674455920 * 95.217460632324 *              -7 * 283.14837646484 *
// *        0 *        3 *   4871674455920 * 788.62329101562 *             -22 * 347.41146850585 *
// *        0 *        4 *   4871674455920 * 347.41143798828 *              -5 *                 *
// *        0 *        5 *   4871674455920 * 187.93092346191 *              -4 *                 *
// *        1 *        0 *   4871674698480 * 326.07614135742 *               9 * 631.66729736328 *
// *        1 *        1 *   4871674698480 * 305.59121704101 *               3 *                 *
// *        2 *        0 *   4871675220490 * 372.71896362304 *             -17 * 372.71896362304 *
// *        2 *        1 *   4871675220490 * 55.163105010986 *             -36 * 55.163108825683 *
// *        3 *        0 *   4871675461980 * 1263.1059570312 *              -6 * 1263.1058349609 *
// *        3 *        1 *   4871675461980 * 421.09942626953 *              -3 * 421.09939575195 *
// ***********************************************************************************************

// %% [markdown]
// #### 验证Chico信息：两文件中的核子飞行角度theta,phi存在一定差异，导致核子质量、速度、Q值以及对gamma的多普勒修正出现偏差

// %%
cout<<"coin0089.root"<<endl;
treeMe->Scan("ts:thetaP:phiP:massP:betaP:pseuQ","","colsize=13",10,0);
cout<<endl<<"g0089.root"<<endl;
treeLi->Scan("ts:thetaP:phiP:MassP:BetaP:Qval1","","colsize=13",10,0);
// Out:
// coin0089.root
// ************************************************************************************************************
// *    Row   *            ts *        thetaP *          phiP *         massP *         betaP *         pseuQ *
// ************************************************************************************************************
// *        0 * 4871674455920 * 0.48303273320 * 4.69690895080 * 129.188751220 * 0.11577975004 * -79.818603515 *
// *        1 * 4871674698480 * 0.59045463800 * 5.84909725189 * 156.739547729 * 0.11136247217 * -74.646667480 *
// *        2 * 4871675220490 * 0.38866677880 * 5.84018802642 * 105.733711242 * 0.11859617382 * -88.684753417 *
// *        3 * 4871675461980 * 0.47806119918 * 5.32299900054 * 144.009170532 * 0.11869154125 * -41.572753906 *
// *        4 * 4871676099280 * 0.39430281519 * 4.57958889007 * 124.522079467 * 0.11413557827 * -147.79626464 *
// *        5 * 4871676380940 * 0.45621305704 * 1.77117228508 * 120.479911804 * 0.12188071757 * -8.5212402343 *
// *        6 * 4871676532370 * 0.38495042920 * 2.08386206626 * 112.119697570 * 0.10546246916 * -263.34234619 *
// *        7 * 4871676725860 * 0.47915494441 * 1.50039935112 * 137.078430175 * 0.11723864078 * -61.521850585 *
// *        8 * 4871677222380 * 0.40416276454 * 3.44583082199 * 123.657546997 * 0.12361989915 * -11.117431640 *
// *        9 * 4871677513200 * 0.42244851589 * 1.72906827926 *   102.6015625 * 0.10352544486 * -269.77722167 *
// ************************************************************************************************************
//
// g0089.root
// ************************************************************************************************************
// *    Row   *            ts *        thetaP *          phiP *         MassP *         BetaP *         Qval1 *
// ************************************************************************************************************
// *        0 * 4871674455920 * 0.48704922199 * 4.70620250701 * 128.680313110 * 0.11612918227 * -48.183837890 *
// *        1 * 4871674698480 * 0.58459061384 * 5.84216690063 * 158.267333984 * 0.11197861284 * -43.348144531 *
// *        2 * 4871675220490 * 0.39015507698 * 5.83903789520 * 105.796043396 * 0.11884912103 * -63.860595703 *
// *        3 * 4871675461980 * 0.48028245568 * 5.32312202453 * 143.519378662 * 0.11872386187 * -12.331787109 *
// *        4 * 4871676099280 * 0.38015604019 * 4.57123994827 * 129.199188232 * 0.11438155174 * -135.24102783 *
// *        5 * 4871676380940 * 0.44303688406 * 1.77466130256 * 123.046173095 * 0.12108998745 *   1.748046875 *
// *        6 * 4871676532370 * 0.38380882143 * 2.08024501800 * 112.130661010 * 0.10525043308 * -255.07141113 *
// *        7 * 4871676725860 * 0.47903987765 * 1.50050377845 * 137.586395263 * 0.11756604164 * -31.246948242 *
// *        8 * 4871677222380 * 0.39744257926 * 3.44570231437 * 125.546607971 * 0.12341178208 * 12.4532470703 *
// *        9 * 4871677513200 * 0.42363208532 * 1.73592376709 * 103.384086608 * 0.10427856445 * -247.73950195 *
// ************************************************************************************************************

// %% [markdown]
// #### 逐文件检查代码，发现这种差异来源于 r2root/sortChico.cc 中对theta,phi进行刻度时，加上了随机数，每次运行结果均不一样
// ``` c++
// if(abs(vcathodemap)==1){
//     theta[l]=(ChicoEvent->cathode_tdc_val[i]-ChicoEvent->cathode_tdc_val[j])*cathodesign;
//     ftheta[l] = gainTheta[anode[l]]*(float)theta[l];
//     ftheta[l] += offTheta[anode[l]];
//     ftheta[l] += (float)rand()/d-0.5;//随机数
//     validT[l]=1;
// }
// if(abs(vcathodemap)==2){
//     phi[l]=(ChicoEvent->cathode_tdc_val[i]-ChicoEvent->cathode_tdc_val[j])*cathodesign;
//     fphi[l] = gainPhi[anode[l]]*(float)phi[l];
//     fphi[l] += offPhi[anode[l]];
//     fphi[l] += 36.0*(float)(anode[l]%10);
//     fphi[l] += (float)rand()/d-0.5;//随机数
//     validP[l]=1;
// }
// ```
