// %% [markdown]
// # prompt-prompt

// %%
TFile *ipfMe = new TFile("ROOT/Gpp_100_109.root");
TTree *treeMe = (TTree*)ipfMe->Get("tree");
TFile *ipfLi = new TFile("ROOT/pp100_109.root");
TTree *treeLi = (TTree*)ipfLi->Get("tree");
TCanvas* c1 = new TCanvas;

// %%
treeMe->Draw("ePx>>pjeMe(1500,0,1500)",
             "np==2 && (eTx<401 || (eTx>411 && eTx<572) || eTx>582) && (eTy<401 || (eTy>411 && eTy<572) || eTy>582)");
TH1D *pjeMe = (TH1D*)gROOT->FindObject("pjeMe");
pjeMe->SetLineColor(kBlue);

treeLi->Draw("px>>pjeLi(1500,0,1500)");
TH1D *pjeLi = (TH1D*)gROOT->FindObject("pjeLi");
pjeLi->SetLineColor(kRed);

// %%
%jsroot on
pjeMe->Draw();
pjeLi->Draw("same");
c1->Draw();
// Out:
// <div id="root_plot_1"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
%jsroot off

// %%
//gROOT->ProcessLine(".x gmatrix.cpp");

// %%
TFile* fmat = new TFile("ROOT/Gppmat.root");
TH2D* hxy = (TH2D*)fmat->Get("hg2xy");
TH2D* hxyp = (TH2D*)fmat->Get("hg2xyp");
TH1D* hx = (TH1D*)fmat->Get("hg2x");
TH1D* hxb = (TH1D*)fmat->Get("hg2xb");
TH1D* hxp = (TH1D*)fmat->Get("hg2xp");

// %%
treeLi->Draw("px:py>>(2000,0,2000,2000,0,2000)","","colz");
c1->SetLogz();
c1->Draw();

// %%
hxy->Draw("colz");
c1->SetLogz();
c1->Draw();

// %%
hxyp->Draw("colz");
c1->SetLogz(0);
c1->Draw();

// %%
%jsroot on

// %%
hx->Draw();
hxb->Draw("same");
hxp->Draw("same");
c1->Draw();
// Out:
// <div id="root_plot_2"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
gROOT->ProcessLine(".x gg.C");
// Out:
// load ROOT file: ROOT/Gppmat.root
// <div id="root_plot_3"
//      style="width: 796px; height: 772px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
newcanvas();
setpeakwidth(-5,5);
setnpeaks(20);
g(349);
// Out:
// <div id="root_plot_4"
//      style="width: 796px; height: 372px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
newcanvas();
setpeakwidth(-10,10);
setnpeaks(20);
g(510);
// Out:
// <div id="root_plot_5"
//      style="width: 796px; height: 372px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
newcanvas();
setpeakwidth(-5,5);
setnpeaks(20);
g(849);
// Out:
// <div id="root_plot_6"
//      style="width: 796px; height: 372px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...
